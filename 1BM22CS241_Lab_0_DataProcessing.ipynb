# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjeet-108/6thSem-ML-Lab/blob/main/1BM22CS241_Lab_0_DataProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Stock Market Data Analysis
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

tickers = ["HDFCBANK.NS", "ICICIBANK.NS", "KOTAKBANK.NS"]



data = yf.download(tickers, start="2024-01-01", end="2024-12-30", group_by='ticker')


print("First 5 rows of the dataset:")
print(data.head())


print("\nShape of the dataset:")
print(data.shape)


print("\nColumn names:")
print(data.columns)

#HDFC
HDFCBANK_data = data['HDFCBANK.NS']
print("\nSummary statistics for HDFCBANK Industries:")
print(HDFCBANK_data.describe())


HDFCBANK_data['Daily Return'] = HDFCBANK_data['Close'].pct_change()

plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
HDFCBANK_data['Close'].plot(title="HDFCBANK_data Industries - Closing Price")
plt.subplot(2, 1, 2)
HDFCBANK_data['Daily Return'].plot(title="HDFCBANK_data Industries - Daily Returns", color='orange')
plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  3 of 3 completed
# <ipython-input-18-cb5d19bf8a46>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HDFCBANK_data['Daily Return'] = HDFCBANK_data['Close'].pct_change()
# First 5 rows of the dataset:
# Ticker     ICICIBANK.NS                                                \
# Price              Open        High         Low       Close    Volume
# Date
# 2024-01-01   983.086778  996.273246  982.541485  990.869812   7683792
# 2024-01-02   988.490253  989.134730  971.883221  973.866150  16263825
# 2024-01-03   976.295294  979.567116  966.777197  975.650818  16826752
# 2024-01-04   977.980767  980.707295  973.519176  978.724365  22789140
# ...

# %%
#ICICI
ICICIBANK_data = data['ICICIBANK.NS']
print("\nSummary statistics for ICICIBANK Industries:")
print(ICICIBANK_data.describe())


ICICIBANK_data['Daily Return'] = ICICIBANK_data['Close'].pct_change()

plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
ICICIBANK_data['Close'].plot(title="ICICIBANK_data Industries - Closing Price")
plt.subplot(2, 1, 2)
ICICIBANK_data['Daily Return'].plot(title="ICICIBANK_data Industries - Daily Returns", color='orange')
plt.tight_layout()
plt.show()
# Out:
# Summary statistics for ICICIBANK Industries:
# Price         Open         High          Low        Close        Volume
# count   244.000000   244.000000   244.000000   244.000000  2.440000e+02
# mean   1161.723560  1173.687900  1151.318979  1162.751791  1.539172e+07
# std     104.905646   105.668229   105.083015   105.520481  9.503609e+06
# min     965.637027   979.567116   961.869473   971.387512  1.007022e+06
# 25%    1073.818215  1085.368782  1067.386038  1075.107086  1.014533e+07
# 50%    1169.443635  1178.450012  1157.361521  1165.470703  1.291768e+07
# 75%    1248.512512  1261.399994  1236.649963  1250.812531  1.755770e+07
# max    1344.900024  1362.349976  1340.050049  1346.099976  7.325777e+07
# <ipython-input-19-57f8d24454fd>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#KOTAK
KOTAKBANK_data = data['KOTAKBANK.NS']
print("\nSummary statistics for KOTAKBANK Industries:")
print(KOTAKBANK_data.describe())


KOTAKBANK_data['Daily Return'] = KOTAKBANK_data['Close'].pct_change()

plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
KOTAKBANK_data['Close'].plot(title="KOTAKBANK_data Industries - Closing Price")
plt.subplot(2, 1, 2)
KOTAKBANK_data['Daily Return'].plot(title="KOTAKBANK_data Industries - Daily Returns", color='orange')
plt.tight_layout()
plt.show()
# Out:
# Summary statistics for KOTAKBANK Industries:
# Price         Open         High          Low        Close        Volume
# count   244.000000   244.000000   244.000000   244.000000  2.440000e+02
# mean   1771.245907  1787.548029  1754.395105  1770.792347  5.736598e+06
# std      62.189675    61.978802    62.765980    62.594747  5.388927e+06
# min    1581.266899  1586.161558  1542.159736  1545.006592  1.824890e+05
# 25%    1733.974927  1754.131905  1719.028421  1736.297058  3.300380e+06
# 50%    1769.500000  1789.450012  1758.099976  1773.681030  4.307680e+06
# 75%    1809.925018  1826.998164  1789.912506  1808.155670  6.159475e+06
# max    1935.000000  1942.000000  1909.599976  1934.699951  6.617908e+07
# <ipython-input-20-503b7ae7a795>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#Method 1 : Initializing values directly into dataframe
import pandas as pd

data={
    'USN':['1BM22CS001','1BM22CS002','1BM22CS003','1BM22CS004','1BM22CS005'],
    'Name':['A','B','C','D','E'],
    'Marks':[96,97,97,98,98]
}

df1=pd.DataFrame(data)
print(df1)
# Out:
#           USN Name  Marks
# 0  1BM22CS001    A     96
# 1  1BM22CS002    B     97
# 2  1BM22CS003    C     97
# 3  1BM22CS004    D     98
# 4  1BM22CS005    E     98

# %%
#Method 2: Importing Datasets from sklearn.datasets
from sklearn.datasets import load_diabetes

diabetes=load_diabetes()
df2=pd.DataFrame(diabetes.data,columns=diabetes.feature_names)
df2['target']=diabetes.target
print(df2.head())
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
#Method 3: Importing Datasets From a .csv file
df3=pd.read_csv('sample_sales_data.csv')
print(df3.head())
# Out:
#     Product  Quantity  Price  Sales Region
# 0    Laptop         5   1000   5000  North
# 1     Mouse        15     20    300   West
# 2  Keyboard        10     50    500   East
# 3   Monitor         8    200   1600  South
# 4    Laptop        12    950  11400  North

# %%
#Method 4: Downloading Datasets from Mendely
df4=pd.read_csv('/content/Dataset of Diabetes .csv')
print(df4.head())
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N
